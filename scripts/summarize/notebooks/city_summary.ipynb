# %%
import os, sys, time
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
import pandas as pd
pd.options.mode.chained_assignment = None
import h5py

# %matplotlib inline

from IPython.display import display, HTML

if (sys.version_info < (3, 0)):
    HTML('''<script>
    code_show=true; 
    function code_toggle() {
     if (code_show){
     $('div.input').hide();
     } else {
     $('div.input').show();
     }
     code_show = !code_show
    } 
    $( document ).ready(code_toggle);
    </script>
    <form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>''')

pd.options.display.max_rows = None

# %%
# Create timestamp to show when this summary was run
print('Summary run: ' + time.strftime("%a, %d %b %Y %H:%M:%S"))
# Out:
# Summary run: Tue, 29 Apr 2025 09:21:27

# %%
pd.options.display.float_format = '{:0,.0f}'.format

# %%
geog = 'city'
geog_col = 'hh_city'

# %% [markdown]
# # City
# Results based on household location

# %% [markdown]
# # Population

# %%
df = pd.read_csv(r'..\..\..\outputs\agg\dash\person_geog.csv')
_df_pop = df.groupby(geog_col).sum()[['psexpfac']]

df = pd.read_csv(r'..\..\..\outputs\agg\dash\hh_geog.csv')
_df_hh = df.groupby(geog_col).sum()[['hhexpfac']]

df = _df_hh.merge(_df_pop, on=geog_col)
df.rename(columns={'hhexpfac': 'Households', 'psexpfac': 'Persons'}, inplace=True)
df.to_csv(os.path.join(os.getcwd(), r'..\..\..\outputs\compare',geog,'1_population.csv'))
df.loc['Total'] = df.sum(axis=0)
df
# Out:
#                              Households   Persons
# hh_city
# Algona                              985     3,147
# Arlington                         7,113    19,189
# Arlington UGA                       167       484
# Auburn                           29,386    80,155
# Auburn PAA                          128       422
# Bainbridge Island                 9,944    24,107
# Bear Creek UPD                    3,985    10,412
# Beaux Arts                          108       322
# Bellevue                         58,021   141,188
# Bellevue PAA                          4        15
# Black Diamond                     1,506     4,158
# Black Diamond PAA                    47       144
# Bonney Lake                       6,979    20,565
# Bonney Lake PAA                   2,474     7,514
# Bothell                          17,865    44,651
# Bothell MUGA                     10,947    31,321
# Bremerton                        15,798    35,477
# Bremerton UGA                     4,090     9,714
# Brier                             2,299     6,568
# Brier MUGA                          604     1,743
# Buckley                           1,739     4,434
# Burien                           19,872    51,824
# Carbonado                           234       663
# Carbonado PAA                         4         8
# Carnation                           783     2,274
# Carnation PAA                        70       201
# Central Kitsap UGA                8,499    23,219
# Clyde Hill                          963     2,951
# Covington                         7,012    20,753
# Darrington                          545     1,319
# Darrington UGA                       30        51
# Des Moines                       11,804    30,460
# DuPont                            3,521     9,303
# Duvall                            2,559     7,689
# Duvall PAA                           53       188
# Eatonville                          921     2,543
# Eatonville PAA                       90       255
# Edgewood                          4,301    11,128
# Edmonds                          18,028    41,390
# Edmonds MUGA                      1,476     3,826
# Enumclaw                          4,781    11,640
# Enumclaw PAA                        301       789
# Everett                          44,159   107,125
# Everett MUGA                     16,920    47,583
# Federal Way                      35,306    96,442
# Federal Way PAA                   7,239    22,089
# Fife                              4,087    10,347
# Fife Milton Overlap                  49       128
# Fife PAA                            111       295
# Fircrest                          2,713     6,500
# Fircrest PAA                         14        32
# Frederickson                        200       607
# Gig Harbor                        4,697    10,591
# Gig Harbor PAA                    2,607     6,745
# Gold Bar                            815     2,219
# Gold Bar UGA                        325       835
# Granite Falls                     1,307     3,638
# Granite Falls UGA                    56       163
# Hunts Point                         162       448
# Index                                50       114
# Issaquah                         15,558    36,691
# Issaquah PAA                         85       262
# JBLM                              2,881    10,056
# Kenmore                           8,717    22,605
# Kent                             45,528   126,720
# Kent PAA                            156       430
# King-Rural                       44,915   128,396
# Kingston UGA                        953     2,247
# Kirkland                         36,723    86,294
# Kitsap-Rural                     39,522   105,727
# Lake Forest Park                  5,236    13,041
# Lake Stevens                     11,215    32,568
# Lake Stevens UGA                  1,841     5,674
# Lake Stickney Gap                 3,531     9,816
# Lakewood                         24,529    58,321
# Lakewood Steilacoom Overlap         898     2,390
# Larch Way Overlap                 1,520     4,727
# Lynnwood                         15,014    37,364
# Lynnwood MUGA                    11,670    31,603
# Maltby UGA                           67       185
# Maple Valley                      8,573    25,452
# Marysville                       23,764    66,749
# Marysville UGA                       58       184
# Meadowdale Gap MUGA               1,018     3,090
# Medina                            1,152     3,255
# Mercer Island                     9,708    24,248
# Mid-County                        3,159     8,571
# Mill Creek                        8,343    20,344
# Mill Creek MUGA                  16,378    48,190
# Milton                            3,332     8,060
# Milton PAA                          514     1,392
# Monroe                            5,563    16,342
# Monroe UGA                          459     1,448
# Mountlake Terrace                 8,800    21,427
# Mountlake Terrace MUGA                9        19
# Mukilteo                          8,377    21,108
# Mukilteo MUGA                     4,942    14,359
# Newcastle                         4,978    12,485
# Newcastle PAA                         2         7
# Normandy Park                     2,631     6,489
# North Bend                        2,601     6,923
# North Bend PAA                      916     2,671
# North Highline                    6,984    19,694
# Orting                            2,644     7,881
# PAINE FIELD AREA                      9        21
# Pacific                           2,381     7,015
# Pacific PAA                         297       864
# Parkland-Spanaway-Midland         4,650    13,936
# Pierce-Rural                     60,637   169,324
# Port Orchard                      5,275    12,665
# Port Orchard UGA                  5,710    14,692
# Poulsbo                           4,343    10,158
# Poulsbo UGA                         229       601
# Puyallup                         15,672    39,213
# Puyallup PAA                      1,412     3,099
# Puyallup PAA - HCT                1,593     4,407
# Redmond                          25,872    63,223
# Redmond PAA                         931     2,889
# Renton                           40,845   103,611
# Renton PAA                       16,832    48,663
# Roy                                 307       831
# Roy PAA                               3         4
# Ruston                              445     1,005
# Sammamish                        21,103    63,568
# Sammamish PAA                       153       520
# SeaTac                           10,207    28,497
# Seattle                         336,894   702,011
# Seattle PAA                          23        54
# Shoreline                        22,731    54,510
# Silver Firs Gap MUGA              5,054    16,184
# Silverdale                        7,495    18,551
# Skykomish                            75       135
# Snohomish                         4,023     9,856
# Snohomish UGA                       502     1,439
# Snohomish-Rural                  46,394   133,890
# Snoqualmie                        4,447    13,518
# Snoqualmie PAA                      252       719
# South Hill                       20,064    59,152
# South Prairie                       198       490
# South Prairie PAA                     2         5
# Stanwood                          2,598     6,744
# Stanwood UGA                         56       151
# Steilacoom                        3,120     7,836
# Sultan                            1,706     4,966
# Sultan UGA                           21        65
# Sumner                            4,145     9,982
# Sumner PAA                          578     1,661
# Tacoma                           83,126   202,244
# Tacoma PAA                       24,027    65,342
# Tukwila                           7,324    19,376
# Tukwila PAA                           6        17
# UU                               14,636    44,200
# UUU                               1,289     3,909
# University Place                 13,529    32,927
# Wilkeson                            163       413
# Woodinville                       4,692    11,932
# Woodway                             463     1,373
# Woodway MUGA                          5        10
# Yarrow Point                        402     1,076
# Total                         1,605,263 4,053,154

# %% [markdown]
# # Employment

# %%
df = pd.read_csv(r'..\..\..\outputs\agg\dash\person_geog.csv')
df = df[df['pwtyp'].isin(['Paid Full-Time Worker', 'Paid Part-Time Worker'])]
_df = df.pivot_table(index=geog_col, columns='pwtyp', aggfunc='sum', values='psexpfac')
_df.to_csv(os.path.join(os.getcwd(), r'..\..\..\outputs\compare',geog,'2_employment.csv'))
_df.loc['Total'] = _df.sum(axis=0)
_df['Total'] = _df.sum(axis=1)
_df
# Out:
# pwtyp                        Paid Full-Time Worker  Paid Part-Time Worker  \
# hh_city
# Algona                                       1,215                    318
# Arlington                                    7,074                  1,908
# Arlington UGA                                  163                     51
# Auburn                                      29,693                  6,695
# Auburn PAA                                     151                     34
# Bainbridge Island                            7,615                  2,233
# Bear Creek UPD                               3,409                    652
# Beaux Arts                                     115                     19
# Bellevue                                    59,288                 10,645
# Bellevue PAA                                     6                    NaN
# Black Diamond                                1,651                    380
# Black Diamond PAA                               47                     15
# Bonney Lake                                  8,216                  1,571
# Bonney Lake PAA                              2,878                    569
# Bothell                                     19,111                  3,833
# Bothell MUGA                                12,951                  2,664
# Bremerton                                   12,989                  3,226
# Bremerton UGA                                3,344                    842
# Brier                                        2,595                    564
# Brier MUGA                                     684                    133
# Buckley                                      1,656                    373
# Burien                                      19,544                  5,209
# Carbonado                                      241                     66
# Carbonado PAA                                    1                      2
# Carnation                                      841                    282
# Carnation PAA                                   83                     33
# Central Kitsap UGA                           8,262                  2,654
# Clyde Hill                                     942                    157
# Covington                                    8,584                  1,859
# Darrington                                     350                    111
# Darrington UGA                                  16                      3
# Des Moines                                  11,345                  2,904
# DuPont                                       3,453                    589
# Duvall                                       3,164                    810
# Duvall PAA                                      74                     14
# Eatonville                                     820                    145
# Eatonville PAA                                  90                     16
# Edgewood                                     4,529                  1,046
# Edmonds                                     17,406                  3,549
# Edmonds MUGA                                 1,559                    365
# Enumclaw                                     4,360                  1,208
# Enumclaw PAA                                   245                     34
# Everett                                     42,420                  9,825
# Everett MUGA                                19,162                  4,110
# Federal Way                                 35,384                  9,131
# Federal Way PAA                              7,696                  2,301
# Fife                                         4,522                    805
# Fife Milton Overlap                             56                      9
# Fife PAA                                       125                     25
# Fircrest                                     2,156                    705
# Fircrest PAA                                    14                      3
# Frederickson                                   234                     47
# Gig Harbor                                   3,400                    764
# Gig Harbor PAA                               2,207                    535
# Gold Bar                                       814                    210
# Gold Bar UGA                                   301                     81
# Granite Falls                                1,282                    323
# Granite Falls UGA                               55                     16
# Hunts Point                                    136                     37
# Index                                           53                     17
# Issaquah                                    15,256                  3,884
# Issaquah PAA                                   106                     21
# JBLM                                         3,394                    584
# Kenmore                                      9,017                  2,074
# Kent                                        50,416                 10,649
# Kent PAA                                       200                     35
# King-Rural                                  47,115                 11,283
# Kingston UGA                                   692                    242
# Kirkland                                    37,615                  8,711
# Kitsap-Rural                                35,072                 10,038
# Lake Forest Park                             5,213                  1,320
# Lake Stevens                                12,436                  3,029
# Lake Stevens UGA                             2,212                    422
# Lake Stickney Gap                            4,082                    664
# Lakewood                                    20,236                  4,987
# Lakewood Steilacoom Overlap                    834                    227
# Larch Way Overlap                            1,921                    304
# Lynnwood                                    14,347                  3,309
# Lynnwood MUGA                               13,197                  2,660
# Maltby UGA                                      83                     12
# Maple Valley                                 9,453                  2,033
# Marysville                                  24,913                  5,954
# Marysville UGA                                  88                      9
# Meadowdale Gap MUGA                          1,213                    297
# Medina                                       1,045                    175
# Mercer Island                                8,495                  2,158
# Mid-County                                   3,512                    639
# Mill Creek                                   8,952                  1,565
# Mill Creek MUGA                             19,789                  3,887
# Milton                                       3,463                    707
# Milton PAA                                     552                    126
# Monroe                                       6,180                  1,345
# Monroe UGA                                     577                    135
# Mountlake Terrace                            9,794                  1,839
# Mountlake Terrace MUGA                          13                    NaN
# Mukilteo                                     8,610                  1,714
# Mukilteo MUGA                                5,557                  1,239
# Newcastle                                    5,175                  1,243
# Newcastle PAA                                    4                    NaN
# Normandy Park                                2,437                    497
# North Bend                                   2,732                    679
# North Bend PAA                               1,035                    287
# North Highline                               7,158                  2,156
# Orting                                       2,754                    685
# PAINE FIELD AREA                                 9                      1
# Pacific                                      2,730                    663
# Pacific PAA                                    316                     94
# Parkland-Spanaway-Midland                    4,959                    952
# Pierce-Rural                                57,509                 14,494
# Port Orchard                                 4,460                    985
# Port Orchard UGA                             4,764                  1,482
# Poulsbo                                      3,292                  1,201
# Poulsbo UGA                                    177                     53
# Puyallup                                    14,976                  3,156
# Puyallup PAA                                 1,234                    306
# Puyallup PAA - HCT                           1,600                    387
# Redmond                                     27,656                  5,012
# Redmond PAA                                  1,136                    232
# Renton                                      43,443                 10,312
# Renton PAA                                  18,660                  4,727
# Roy                                            266                     62
# Roy PAA                                          3                    NaN
# Ruston                                         328                    108
# Sammamish                                   23,985                  5,414
# Sammamish PAA                                  195                     41
# SeaTac                                      11,047                  2,528
# Seattle                                    330,693                 72,113
# Seattle PAA                                     26                      3
# Shoreline                                   22,148                  5,589
# Silver Firs Gap MUGA                         6,478                  1,373
# Silverdale                                   7,098                  1,860
# Skykomish                                       60                     26
# Snohomish                                    3,754                    989
# Snohomish UGA                                  535                    123
# Snohomish-Rural                             48,650                 12,536
# Snoqualmie                                   5,253                  1,281
# Snoqualmie PAA                                 292                     89
# South Hill                                  21,783                  4,643
# South Prairie                                  195                     41
# South Prairie PAA                                3                    NaN
# Stanwood                                     2,493                    732
# Stanwood UGA                                    59                      9
# Steilacoom                                   2,875                    570
# Sultan                                       1,886                    415
# Sultan UGA                                      17                      7
# Sumner                                       3,858                    823
# Sumner PAA                                     717                    162
# Tacoma                                      74,903                 19,729
# Tacoma PAA                                  22,611                  5,658
# Tukwila                                      7,990                  1,961
# Tukwila PAA                                      6                      1
# UU                                          16,330                  3,355
# UUU                                          1,460                    388
# University Place                            12,363                  3,041
# Wilkeson                                       170                     33
# Woodinville                                  4,663                    991
# Woodway                                        450                    100
# Woodway MUGA                                     7                    NaN
# Yarrow Point                                   366                     69
# Total                                    1,610,659                371,469
#
# pwtyp                           Total
# hh_city
# Algona                          1,533
# Arlington                       8,982
# Arlington UGA                     214
# Auburn                         36,388
# Auburn PAA                        185
# Bainbridge Island               9,848
# Bear Creek UPD                  4,061
# Beaux Arts                        134
# Bellevue                       69,933
# Bellevue PAA                        6
# Black Diamond                   2,031
# Black Diamond PAA                  62
# Bonney Lake                     9,787
# Bonney Lake PAA                 3,447
# Bothell                        22,944
# Bothell MUGA                   15,615
# Bremerton                      16,215
# Bremerton UGA                   4,186
# Brier                           3,159
# Brier MUGA                        817
# Buckley                         2,029
# Burien                         24,753
# Carbonado                         307
# Carbonado PAA                       3
# Carnation                       1,123
# Carnation PAA                     116
# Central Kitsap UGA             10,916
# Clyde Hill                      1,099
# Covington                      10,443
# Darrington                        461
# Darrington UGA                     19
# Des Moines                     14,249
# DuPont                          4,042
# Duvall                          3,974
# Duvall PAA                         88
# Eatonville                        965
# Eatonville PAA                    106
# Edgewood                        5,575
# Edmonds                        20,955
# Edmonds MUGA                    1,924
# Enumclaw                        5,568
# Enumclaw PAA                      279
# Everett                        52,245
# Everett MUGA                   23,272
# Federal Way                    44,515
# Federal Way PAA                 9,997
# Fife                            5,327
# Fife Milton Overlap                65
# Fife PAA                          150
# Fircrest                        2,861
# Fircrest PAA                       17
# Frederickson                      281
# Gig Harbor                      4,164
# Gig Harbor PAA                  2,742
# Gold Bar                        1,024
# Gold Bar UGA                      382
# Granite Falls                   1,605
# Granite Falls UGA                  71
# Hunts Point                       173
# Index                              70
# Issaquah                       19,140
# Issaquah PAA                      127
# JBLM                            3,978
# Kenmore                        11,091
# Kent                           61,065
# Kent PAA                          235
# King-Rural                     58,398
# Kingston UGA                      934
# Kirkland                       46,326
# Kitsap-Rural                   45,110
# Lake Forest Park                6,533
# Lake Stevens                   15,465
# Lake Stevens UGA                2,634
# Lake Stickney Gap               4,746
# Lakewood                       25,223
# Lakewood Steilacoom Overlap     1,061
# Larch Way Overlap               2,225
# Lynnwood                       17,656
# Lynnwood MUGA                  15,857
# Maltby UGA                         95
# Maple Valley                   11,486
# Marysville                     30,867
# Marysville UGA                     97
# Meadowdale Gap MUGA             1,510
# Medina                          1,220
# Mercer Island                  10,653
# Mid-County                      4,151
# Mill Creek                     10,517
# Mill Creek MUGA                23,676
# Milton                          4,170
# Milton PAA                        678
# Monroe                          7,525
# Monroe UGA                        712
# Mountlake Terrace              11,633
# Mountlake Terrace MUGA             13
# Mukilteo                       10,324
# Mukilteo MUGA                   6,796
# Newcastle                       6,418
# Newcastle PAA                       4
# Normandy Park                   2,934
# North Bend                      3,411
# North Bend PAA                  1,322
# North Highline                  9,314
# Orting                          3,439
# PAINE FIELD AREA                   10
# Pacific                         3,393
# Pacific PAA                       410
# Parkland-Spanaway-Midland       5,911
# Pierce-Rural                   72,003
# Port Orchard                    5,445
# Port Orchard UGA                6,246
# Poulsbo                         4,493
# Poulsbo UGA                       230
# Puyallup                       18,132
# Puyallup PAA                    1,540
# Puyallup PAA - HCT              1,987
# Redmond                        32,668
# Redmond PAA                     1,368
# Renton                         53,755
# Renton PAA                     23,387
# Roy                               328
# Roy PAA                             3
# Ruston                            436
# Sammamish                      29,399
# Sammamish PAA                     236
# SeaTac                         13,575
# Seattle                       402,806
# Seattle PAA                        29
# Shoreline                      27,737
# Silver Firs Gap MUGA            7,851
# Silverdale                      8,958
# Skykomish                          86
# Snohomish                       4,743
# Snohomish UGA                     658
# Snohomish-Rural                61,186
# Snoqualmie                      6,534
# Snoqualmie PAA                    381
# South Hill                     26,426
# South Prairie                     236
# South Prairie PAA                   3
# Stanwood                        3,225
# Stanwood UGA                       68
# Steilacoom                      3,445
# Sultan                          2,301
# Sultan UGA                         24
# Sumner                          4,681
# Sumner PAA                        879
# Tacoma                         94,632
# Tacoma PAA                     28,269
# Tukwila                         9,951
# Tukwila PAA                         7
# UU                             19,685
# UUU                             1,848
# University Place               15,404
# Wilkeson                          203
# Woodinville                     5,654
# Woodway                           550
# Woodway MUGA                        7
# Yarrow Point                      435
# Total                       1,982,128

# %% [markdown]
# ### Transit Ridership
#
# #### Total trips

# %%
# Region
# By Agency

# Transit Trips from Daysim, by location
df = pd.read_csv(r'..\..\..\outputs\agg\dash\mode_share_'+geog+'.csv')
_df = df[df['mode']=='Transit'].groupby(geog_col).sum()[['trexpfac']]
_df.to_csv(os.path.join(os.getcwd(), r'..\..\..\outputs\compare',geog,'3_transit_trips.csv'))
_df.loc['Total'] = _df.sum(axis=0)
_df
# Out:
#                              trexpfac
# hh_city
# Algona                            413
# Arlington                         543
# Arlington UGA                      11
# Auburn                          9,352
# Auburn PAA                         34
# Bainbridge Island               7,849
# Bear Creek UPD                    579
# Beaux Arts                         40
# Bellevue                       20,002
# Bellevue PAA                        2
# Black Diamond                     184
# Bonney Lake                       670
# Bonney Lake PAA                   173
# Bothell                         3,887
# Bothell MUGA                    1,831
# Bremerton                       5,647
# Bremerton UGA                   1,073
# Brier                             470
# Brier MUGA                        143
# Buckley                            91
# Burien                          7,501
# Carbonado                          18
# Carnation                          98
# Carnation PAA                       9
# Central Kitsap UGA              1,884
# Clyde Hill                        421
# Covington                       1,748
# Darrington                         65
# Des Moines                      4,183
# DuPont                            118
# Duvall                            343
# Duvall PAA                         10
# Eatonville                         20
# Eatonville PAA                      2
# Edgewood                          624
# Edmonds                         4,268
# Edmonds MUGA                      368
# Enumclaw                          789
# Enumclaw PAA                       37
# Everett                         9,551
# Everett MUGA                    3,486
# Federal Way                     8,729
# Federal Way PAA                 1,582
# Fife                              534
# Fife Milton Overlap                11
# Fife PAA                            9
# Fircrest                          351
# Frederickson                        9
# Gig Harbor                        221
# Gig Harbor PAA                    105
# Gold Bar                           57
# Gold Bar UGA                       20
# Granite Falls                     119
# Granite Falls UGA                   2
# Hunts Point                        63
# Index                               2
# Issaquah                        3,567
# Issaquah PAA                       18
# JBLM                              129
# Kenmore                         2,224
# Kent                           19,365
# Kent PAA                           51
# King-Rural                      6,750
# Kingston UGA                      220
# Kirkland                        9,917
# Kitsap-Rural                    4,427
# Lake Forest Park                1,409
# Lake Stevens                    1,280
# Lake Stevens UGA                  133
# Lake Stickney Gap                 756
# Lakewood                        2,208
# Lakewood Steilacoom Overlap        65
# Larch Way Overlap                 332
# Lynnwood                        4,077
# Lynnwood MUGA                   2,990
# Maltby UGA                         10
# Maple Valley                    1,610
# Marysville                      3,421
# Marysville UGA                      9
# Meadowdale Gap MUGA               203
# Medina                            516
# Mercer Island                   4,338
# Mid-County                        323
# Mill Creek                      1,697
# Mill Creek MUGA                 2,905
# Milton                            466
# Milton PAA                        111
# Monroe                            528
# Monroe UGA                         59
# Mountlake Terrace               2,369
# Mountlake Terrace MUGA              3
# Mukilteo                        1,310
# Mukilteo MUGA                   1,016
# Newcastle                       1,149
# Normandy Park                     741
# North Bend                        339
# North Bend PAA                    101
# North Highline                  2,582
# Orting                            118
# PAINE FIELD AREA                    2
# Pacific                           623
# Pacific PAA                        24
# Parkland-Spanaway-Midland         496
# Pierce-Rural                    2,950
# Port Orchard                      730
# Port Orchard UGA                1,019
# Poulsbo                           799
# Poulsbo UGA                        48
# Puyallup                        2,843
# Puyallup PAA                      210
# Puyallup PAA - HCT                271
# Redmond                         6,621
# Redmond PAA                       161
# Renton                         10,527
# Renton PAA                      4,581
# Roy                                12
# Ruston                             61
# Sammamish                       3,549
# Sammamish PAA                      19
# SeaTac                          7,034
# Seattle                       202,034
# Seattle PAA                        12
# Shoreline                       7,878
# Silver Firs Gap MUGA              870
# Silverdale                      1,177
# Snohomish                         550
# Snohomish UGA                      89
# Snohomish-Rural                 3,494
# Snoqualmie                        787
# Snoqualmie PAA                     59
# South Hill                      1,953
# South Prairie                       8
# Stanwood                          154
# Stanwood UGA                        2
# Steilacoom                        273
# Sultan                            127
# Sumner                            580
# Sumner PAA                         80
# Tacoma                         15,053
# Tacoma PAA                      2,882
# Tukwila                         3,887
# Tukwila PAA                         2
# UU                                857
# UUU                               181
# University Place                1,861
# Wilkeson                            7
# Woodinville                       897
# Woodway                            90
# Woodway MUGA                        2
# Yarrow Point                      126
# Total                         474,745

# %% [markdown]
# #### % Commute Trips by Transit (Home to Work direct)

# %%
# Mode share
df = df[df['dpurp'] == 'Work']
_df = df.pivot_table(index=[geog_col, 'mode'], aggfunc='sum', values='trexpfac').reset_index()
_df_tot = _df.groupby(geog_col).sum()[['trexpfac']]
_df = _df.merge(_df_tot, how='left', on=geog_col)
_df['mode_share'] = _df['trexpfac_x']/_df['trexpfac_y']

_df = _df[_df['mode'] == 'Transit'][[geog_col,'mode_share']]
pd.options.display.float_format = '{:0,.1%}'.format
_df.to_csv(os.path.join(os.getcwd(), r'..\..\..\outputs\compare',geog,'4_transit_commute_share.csv'))
_df
# Out:
#                           hh_city  mode_share
# 5                          Algona        5.5%
# 12                      Arlington        1.9%
# 19                  Arlington UGA        2.0%
# 27                         Auburn        6.3%
# 34                     Auburn PAA        7.3%
# 42              Bainbridge Island       15.3%
# 49                 Bear Creek UPD        3.8%
# 55                     Beaux Arts        1.0%
# 63                       Bellevue        4.8%
# 66                   Bellevue PAA       14.3%
# 72                  Black Diamond        3.2%
# 83                    Bonney Lake        2.7%
# 90                Bonney Lake PAA        2.4%
# 98                        Bothell        3.8%
# 106                  Bothell MUGA        3.8%
# 114                     Bremerton        7.6%
# 121                 Bremerton UGA        5.3%
# 128                         Brier        3.9%
# 135                    Brier MUGA        4.5%
# 142                       Buckley        2.1%
# 150                        Burien        4.5%
# 156                     Carbonado        2.6%
# 164                     Carnation        3.3%
# 169                 Carnation PAA        2.7%
# 176            Central Kitsap UGA        3.6%
# 183                    Clyde Hill        4.9%
# 190                     Covington        4.6%
# 197                    Darrington        0.8%
# 207                    Des Moines        4.7%
# 214                        DuPont        2.3%
# 221                        Duvall        3.0%
# 227                    Duvall PAA        5.0%
# 234                    Eatonville        1.2%
# 241                Eatonville PAA        0.9%
# 248                      Edgewood        3.6%
# 256                       Edmonds        4.0%
# 263                  Edmonds MUGA        4.1%
# 270                      Enumclaw        3.7%
# 277                  Enumclaw PAA        3.8%
# 285                       Everett        2.7%
# 292                  Everett MUGA        3.2%
# 300                   Federal Way        3.5%
# 307               Federal Way PAA        3.7%
# 314                          Fife        2.9%
# 321           Fife Milton Overlap        3.6%
# 327                      Fife PAA        2.4%
# 334                      Fircrest        3.1%
# 343                  Frederickson        1.5%
# 350                    Gig Harbor        1.1%
# 357                Gig Harbor PAA        1.1%
# 364                      Gold Bar        1.8%
# 370                  Gold Bar UGA        2.3%
# 377                 Granite Falls        1.2%
# 383             Granite Falls UGA        1.3%
# 390                   Hunts Point        6.5%
# 396                         Index        2.3%
# 403                      Issaquah        4.8%
# 409                  Issaquah PAA        4.9%
# 416                          JBLM        2.2%
# 423                       Kenmore        4.4%
# 431                          Kent        6.9%
# 438                      Kent PAA        4.4%
# 446                    King-Rural        3.9%
# 453                  Kingston UGA        4.3%
# 461                      Kirkland        4.0%
# 469                  Kitsap-Rural        2.9%
# 476              Lake Forest Park        4.2%
# 483                  Lake Stevens        2.2%
# 490              Lake Stevens UGA        2.3%
# 497             Lake Stickney Gap        3.3%
# 505                      Lakewood        2.5%
# 512   Lakewood Steilacoom Overlap        1.5%
# 519             Larch Way Overlap        3.2%
# 526                      Lynnwood        3.8%
# 533                 Lynnwood MUGA        3.3%
# 538                    Maltby UGA        5.4%
# 545                  Maple Valley        3.7%
# 553                    Marysville        2.5%
# 559                Marysville UGA        1.8%
# 566           Meadowdale Gap MUGA        4.0%
# 573                        Medina        7.7%
# 580                 Mercer Island        5.3%
# 587                    Mid-County        2.9%
# 594                    Mill Creek        3.4%
# 602               Mill Creek MUGA        3.4%
# 609                        Milton        2.8%
# 616                    Milton PAA        3.9%
# 623                        Monroe        2.0%
# 630                    Monroe UGA        3.9%
# 637             Mountlake Terrace        4.0%
# 647                      Mukilteo        3.3%
# 655                 Mukilteo MUGA        3.2%
# 662                     Newcastle        4.0%
# 670                 Normandy Park        4.6%
# 677                    North Bend        3.2%
# 685                North Bend PAA        3.6%
# 692                North Highline        4.1%
# 699                        Orting        1.7%
# 708                       Pacific        4.1%
# 714                   Pacific PAA        2.5%
# 721     Parkland-Spanaway-Midland        3.0%
# 729                  Pierce-Rural        1.9%
# 736                  Port Orchard        3.7%
# 743              Port Orchard UGA        4.2%
# 751                       Poulsbo        3.3%
# 758                   Poulsbo UGA        4.4%
# 766                      Puyallup        5.2%
# 773                  Puyallup PAA        3.7%
# 781            Puyallup PAA - HCT        3.7%
# 789                       Redmond        3.9%
# 796                   Redmond PAA        3.2%
# 804                        Renton        3.5%
# 812                    Renton PAA        3.8%
# 819                           Roy        2.1%
# 827                        Ruston        3.3%
# 835                     Sammamish        3.9%
# 842                 Sammamish PAA        3.8%
# 850                        SeaTac        8.1%
# 858                       Seattle        7.4%
# 871                     Shoreline        4.8%
# 878          Silver Firs Gap MUGA        3.0%
# 885                    Silverdale        3.1%
# 897                     Snohomish        2.7%
# 904                 Snohomish UGA        3.1%
# 912               Snohomish-Rural        2.5%
# 920                    Snoqualmie        3.6%
# 926                Snoqualmie PAA        5.1%
# 933                    South Hill        2.6%
# 939                 South Prairie        1.7%
# 947                      Stanwood        1.8%
# 952                  Stanwood UGA        1.5%
# 959                    Steilacoom        2.2%
# 966                        Sultan        2.3%
# 975                        Sumner        4.1%
# 982                    Sumner PAA        3.4%
# 990                        Tacoma        3.3%
# 998                    Tacoma PAA        2.9%
# 1005                      Tukwila        6.1%
# 1010                  Tukwila PAA       13.6%
# 1018                           UU        2.2%
# 1025                          UUU        3.2%
# 1032             University Place        2.9%
# 1038                     Wilkeson        1.8%
# 1045                  Woodinville        3.1%
# 1052                      Woodway        4.0%
# 1055                 Woodway MUGA       25.0%
# 1061                 Yarrow Point        4.3%

# %% [markdown]
# ## VMT

# %%
pd.options.display.float_format = '{:0,.0f}'.format
# aggfunc sum trips filtered by dorp==1 and auto modes | groupby hh_rg_proposed
# hh_rg_proposed, 
df = pd.read_csv(r'..\..\..\outputs\agg\dash\person_vmt.csv')
df = df[(df['dorp'] == 1) & (df['mode'].isin(['SOV','HOV2','HOV3+']))]
_df = df.groupby(geog_col).sum()[['travdist_wt']]
_df['% of VMT'] = (_df/_df.sum()).astype('float')
_df.rename(columns={'travdist_wt': 'VMT'}, inplace=True)
_df.to_csv(os.path.join(os.getcwd(), r'..\..\..\outputs\compare',geog,'5_vmt.csv'))
_df[['VMT']].plot(kind='barh', alpha=0.6)
_df.loc['Total'] = _df.sum(axis=0)
_df['% of VMT'] = _df['% of VMT'].apply('{:0,.1%}'.format)
_df
# Out:
#                                    VMT % of VMT
# hh_city
# Algona                          58,916     0.1%
# Arlington                      391,572     0.5%
# Arlington UGA                   10,192     0.0%
# Auburn                       1,441,420     2.0%
# Auburn PAA                       6,706     0.0%
# Bainbridge Island              241,370     0.3%
# Bear Creek UPD                 255,826     0.4%
# Beaux Arts                       4,796     0.0%
# Bellevue                     2,139,171     3.0%
# Bellevue PAA                       164     0.0%
# Black Diamond                  133,961     0.2%
# Black Diamond PAA                5,722     0.0%
# Bonney Lake                    443,904     0.6%
# Bonney Lake PAA                159,972     0.2%
# Bothell                        819,993     1.1%
# Bothell MUGA                   574,924     0.8%
# Bremerton                      341,056     0.5%
# Bremerton UGA                  119,860     0.2%
# Brier                          123,707     0.2%
# Brier MUGA                      33,663     0.0%
# Buckley                         91,114     0.1%
# Burien                         834,977     1.2%
# Carbonado                       24,771     0.0%
# Carbonado PAA                      227     0.0%
# Carnation                       66,345     0.1%
# Carnation PAA                    6,318     0.0%
# Central Kitsap UGA             322,111     0.5%
# Clyde Hill                      43,431     0.1%
# Covington                      457,350     0.6%
# Darrington                      83,343     0.1%
# Darrington UGA                   3,733     0.0%
# Des Moines                     590,897     0.8%
# DuPont                         137,669     0.2%
# Duvall                         204,723     0.3%
# Duvall PAA                       5,241     0.0%
# Eatonville                      47,412     0.1%
# Eatonville PAA                   9,115     0.0%
# Edgewood                       236,472     0.3%
# Edmonds                        701,910     1.0%
# Edmonds MUGA                    66,232     0.1%
# Enumclaw                       220,757     0.3%
# Enumclaw PAA                    18,478     0.0%
# Everett                      1,590,125     2.2%
# Everett MUGA                   841,754     1.2%
# Federal Way                  1,794,216     2.5%
# Federal Way PAA                449,785     0.6%
# Fife                           170,617     0.2%
# Fife Milton Overlap              2,592     0.0%
# Fife PAA                         6,328     0.0%
# Fircrest                        83,064     0.1%
# Fircrest PAA                       567     0.0%
# Frederickson                    11,105     0.0%
# Gig Harbor                     134,145     0.2%
# Gig Harbor PAA                 104,535     0.1%
# Gold Bar                       104,907     0.1%
# Gold Bar UGA                    42,579     0.1%
# Granite Falls                  107,560     0.2%
# Granite Falls UGA                5,502     0.0%
# Hunts Point                      8,592     0.0%
# Index                            5,811     0.0%
# Issaquah                       699,755     1.0%
# Issaquah PAA                     6,039     0.0%
# JBLM                           167,220     0.2%
# Kenmore                        436,320     0.6%
# Kent                         2,277,405     3.2%
# Kent PAA                         8,561     0.0%
# King-Rural                   3,782,253     5.3%
# Kingston UGA                    50,149     0.1%
# Kirkland                     1,504,326     2.1%
# Kitsap-Rural                 2,482,849     3.5%
# Lake Forest Park               251,127     0.4%
# Lake Stevens                   709,209     1.0%
# Lake Stevens UGA               128,131     0.2%
# Lake Stickney Gap              178,089     0.2%
# Lakewood                       798,042     1.1%
# Lakewood Steilacoom Overlap     36,292     0.1%
# Larch Way Overlap               87,703     0.1%
# Lynnwood                       517,692     0.7%
# Lynnwood MUGA                  542,982     0.8%
# Maltby UGA                       4,889     0.0%
# Maple Valley                   621,737     0.9%
# Marysville                   1,267,431     1.8%
# Marysville UGA                   3,987     0.0%
# Meadowdale Gap MUGA             59,471     0.1%
# Medina                          51,672     0.1%
# Mercer Island                  469,648     0.7%
# Mid-County                     161,726     0.2%
# Mill Creek                     389,985     0.5%
# Mill Creek MUGA                889,240     1.2%
# Milton                         158,023     0.2%
# Milton PAA                      29,837     0.0%
# Monroe                         323,398     0.5%
# Monroe UGA                      34,704     0.0%
# Mountlake Terrace              353,775     0.5%
# Mountlake Terrace MUGA             247     0.0%
# Mukilteo                       465,080     0.7%
# Mukilteo MUGA                  277,158     0.4%
# Newcastle                      262,294     0.4%
# Newcastle PAA                      120     0.0%
# Normandy Park                  131,689     0.2%
# North Bend                     181,451     0.3%
# North Bend PAA                  87,943     0.1%
# North Highline                 286,780     0.4%
# Orting                         183,860     0.3%
# PAINE FIELD AREA                   683     0.0%
# Pacific                        131,407     0.2%
# Pacific PAA                     19,150     0.0%
# Parkland-Spanaway-Midland      251,646     0.4%
# Pierce-Rural                 4,469,684     6.3%
# Port Orchard                   159,845     0.2%
# Port Orchard UGA               185,248     0.3%
# Poulsbo                        117,625     0.2%
# Poulsbo UGA                      8,404     0.0%
# Puyallup                       546,476     0.8%
# Puyallup PAA                    54,873     0.1%
# Puyallup PAA - HCT              73,566     0.1%
# Redmond                      1,021,171     1.4%
# Redmond PAA                     60,941     0.1%
# Renton                       1,801,961     2.5%
# Renton PAA                   1,022,823     1.4%
# Roy                             26,790     0.0%
# Roy PAA                            202     0.0%
# Ruston                          15,962     0.0%
# Sammamish                    1,505,974     2.1%
# Sammamish PAA                   13,463     0.0%
# SeaTac                         421,873     0.6%
# Seattle                      7,469,860    10.5%
# Seattle PAA                      1,314     0.0%
# Shoreline                      947,754     1.3%
# Silver Firs Gap MUGA           343,341     0.5%
# Silverdale                     276,256     0.4%
# Skykomish                        9,344     0.0%
# Snohomish                      180,729     0.3%
# Snohomish UGA                   31,132     0.0%
# Snohomish-Rural              4,183,580     5.9%
# Snoqualmie                     371,840     0.5%
# Snoqualmie PAA                  18,564     0.0%
# South Hill                   1,033,884     1.4%
# South Prairie                   16,430     0.0%
# South Prairie PAA                   88     0.0%
# Stanwood                       126,199     0.2%
# Stanwood UGA                     4,398     0.0%
# Steilacoom                     161,696     0.2%
# Sultan                         156,647     0.2%
# Sultan UGA                       2,355     0.0%
# Sumner                         154,257     0.2%
# Sumner PAA                      37,300     0.1%
# Tacoma                       2,679,441     3.7%
# Tacoma PAA                   1,067,335     1.5%
# Tukwila                        293,015     0.4%
# Tukwila PAA                        175     0.0%
# UU                             863,544     1.2%
# UUU                             93,343     0.1%
# University Place               466,321     0.7%
# Wilkeson                        12,117     0.0%
# Woodinville                    217,077     0.3%
# Woodway                         24,907     0.0%
# Woodway MUGA                       185     0.0%
# Yarrow Point                    21,097     0.0%
# Total                       71,478,893   100.0%

# %%
pd.options.display.float_format = '{:0,.0f}'.format
# aggfunc sum trips filtered by dorp==1 and auto modes | groupby hh_rg_proposed
# hh_rg_proposed, 
df = pd.read_csv(r'..\..\..\outputs\agg\dash\person_vht.csv')
df = df[(df['dorp'] == 1) & (df['mode'].isin(['SOV','HOV2','HOV3+']))]
_df = df.groupby(geog_col).sum()[['travtime_wt']]/60.0
_df['% of VHT'] = (_df/_df.sum()).astype('float')
_df.rename(columns={'travtime_wt': 'VHT'}, inplace=True)
_df[['VHT']].plot(kind='barh', alpha=0.6)
_df.loc['Total'] = _df.sum(axis=0)
_df['% of VHT'] = _df['% of VHT'].apply('{:0,.1%}'.format)
_df.to_csv(os.path.join(os.getcwd(), r'..\..\..\outputs\compare',geog,'6_vht.csv'))
_df
# Out:
#                                   VHT % of VHT
# hh_city
# Algona                          2,288     0.1%
# Arlington                      13,970     0.4%
# Arlington UGA                     369     0.0%
# Auburn                         60,440     1.9%
# Auburn PAA                        290     0.0%
# Bainbridge Island              11,568     0.4%
# Bear Creek UPD                 10,112     0.3%
# Beaux Arts                        223     0.0%
# Bellevue                       95,716     3.1%
# Bellevue PAA                        7     0.0%
# Black Diamond                   4,807     0.2%
# Black Diamond PAA                 202     0.0%
# Bonney Lake                    17,296     0.6%
# Bonney Lake PAA                 6,488     0.2%
# Bothell                        37,058     1.2%
# Bothell MUGA                   26,563     0.9%
# Bremerton                      17,403     0.6%
# Bremerton UGA                   5,743     0.2%
# Brier                           5,937     0.2%
# Brier MUGA                      1,610     0.1%
# Buckley                         3,366     0.1%
# Burien                         37,325     1.2%
# Carbonado                         806     0.0%
# Carbonado PAA                       8     0.0%
# Carnation                       2,166     0.1%
# Carnation PAA                     208     0.0%
# Central Kitsap UGA             14,253     0.5%
# Clyde Hill                      1,917     0.1%
# Covington                      17,720     0.6%
# Darrington                      2,093     0.1%
# Darrington UGA                     93     0.0%
# Des Moines                     24,913     0.8%
# DuPont                          4,995     0.2%
# Duvall                          7,865     0.3%
# Duvall PAA                        201     0.0%
# Eatonville                      1,750     0.1%
# Eatonville PAA                    349     0.0%
# Edgewood                        9,873     0.3%
# Edmonds                        33,789     1.1%
# Edmonds MUGA                    3,109     0.1%
# Enumclaw                        8,250     0.3%
# Enumclaw PAA                      688     0.0%
# Everett                        74,056     2.4%
# Everett MUGA                   37,080     1.2%
# Federal Way                    73,431     2.4%
# Federal Way PAA                18,085     0.6%
# Fife                            7,166     0.2%
# Fife Milton Overlap               104     0.0%
# Fife PAA                          256     0.0%
# Fircrest                        3,986     0.1%
# Fircrest PAA                       27     0.0%
# Frederickson                      485     0.0%
# Gig Harbor                      5,353     0.2%
# Gig Harbor PAA                  4,081     0.1%
# Gold Bar                        3,330     0.1%
# Gold Bar UGA                    1,335     0.0%
# Granite Falls                   3,734     0.1%
# Granite Falls UGA                 189     0.0%
# Hunts Point                       365     0.0%
# Index                             187     0.0%
# Issaquah                       27,733     0.9%
# Issaquah PAA                      240     0.0%
# JBLM                            6,916     0.2%
# Kenmore                        21,615     0.7%
# Kent                           94,805     3.1%
# Kent PAA                          348     0.0%
# King-Rural                    143,757     4.6%
# Kingston UGA                    1,874     0.1%
# Kirkland                       67,259     2.2%
# Kitsap-Rural                   92,202     3.0%
# Lake Forest Park               12,344     0.4%
# Lake Stevens                   27,135     0.9%
# Lake Stevens UGA                5,146     0.2%
# Lake Stickney Gap               7,867     0.3%
# Lakewood                       36,513     1.2%
# Lakewood Steilacoom Overlap     1,601     0.1%
# Larch Way Overlap               4,037     0.1%
# Lynnwood                       25,293     0.8%
# Lynnwood MUGA                  24,539     0.8%
# Maltby UGA                        190     0.0%
# Maple Valley                   23,116     0.7%
# Marysville                     49,490     1.6%
# Marysville UGA                    152     0.0%
# Meadowdale Gap MUGA             2,675     0.1%
# Medina                          2,342     0.1%
# Mercer Island                  20,355     0.7%
# Mid-County                      6,818     0.2%
# Mill Creek                     17,836     0.6%
# Mill Creek MUGA                40,323     1.3%
# Milton                          6,419     0.2%
# Milton PAA                      1,178     0.0%
# Monroe                         12,162     0.4%
# Monroe UGA                      1,319     0.0%
# Mountlake Terrace              16,876     0.5%
# Mountlake Terrace MUGA             13     0.0%
# Mukilteo                       19,405     0.6%
# Mukilteo MUGA                  11,996     0.4%
# Newcastle                      11,183     0.4%
# Newcastle PAA                       6     0.0%
# Normandy Park                   5,473     0.2%
# North Bend                      5,324     0.2%
# North Bend PAA                  2,520     0.1%
# North Highline                 14,327     0.5%
# Orting                          7,377     0.2%
# PAINE FIELD AREA                   26     0.0%
# Pacific                         5,390     0.2%
# Pacific PAA                       775     0.0%
# Parkland-Spanaway-Midland      11,050     0.4%
# Pierce-Rural                  175,733     5.7%
# Port Orchard                    7,073     0.2%
# Port Orchard UGA                8,051     0.3%
# Poulsbo                         4,814     0.2%
# Poulsbo UGA                       330     0.0%
# Puyallup                       24,503     0.8%
# Puyallup PAA                    2,328     0.1%
# Puyallup PAA - HCT              3,185     0.1%
# Redmond                        44,390     1.4%
# Redmond PAA                     2,577     0.1%
# Renton                         81,368     2.6%
# Renton PAA                     45,154     1.5%
# Roy                             1,020     0.0%
# Roy PAA                             8     0.0%
# Ruston                            762     0.0%
# Sammamish                      58,809     1.9%
# Sammamish PAA                     493     0.0%
# SeaTac                         18,734     0.6%
# Seattle                       423,980    13.6%
# Seattle PAA                        61     0.0%
# Shoreline                      45,408     1.5%
# Silver Firs Gap MUGA           14,597     0.5%
# Silverdale                     11,045     0.4%
# Skykomish                         245     0.0%
# Snohomish                       7,294     0.2%
# Snohomish UGA                   1,207     0.0%
# Snohomish-Rural               151,733     4.9%
# Snoqualmie                     11,194     0.4%
# Snoqualmie PAA                    560     0.0%
# South Hill                     45,555     1.5%
# South Prairie                     597     0.0%
# South Prairie PAA                   4     0.0%
# Stanwood                        4,065     0.1%
# Stanwood UGA                      130     0.0%
# Steilacoom                      7,007     0.2%
# Sultan                          5,362     0.2%
# Sultan UGA                         77     0.0%
# Sumner                          6,476     0.2%
# Sumner PAA                      1,499     0.0%
# Tacoma                        130,904     4.2%
# Tacoma PAA                     46,109     1.5%
# Tukwila                        13,009     0.4%
# Tukwila PAA                         8     0.0%
# UU                             36,516     1.2%
# UUU                             3,633     0.1%
# University Place               22,422     0.7%
# Wilkeson                          421     0.0%
# Woodinville                     9,409     0.3%
# Woodway                         1,181     0.0%
# Woodway MUGA                        9     0.0%
# Yarrow Point                      842     0.0%
# Total                       3,106,305   100.0%

# %% [markdown]
# ## Delay
# Calculated based on Household Location

# %%
# might need to be calculated individually?
# create a delay summary from total vmt and total sov_ff_time

# %%
df = pd.read_csv(r'..\..\..\outputs\agg\dash\trip_time_total.csv')
df = df.groupby(geog_col).sum()[['travtime_wt']]

df2 = pd.read_csv(r'..\..\..\outputs\agg\dash\trip_sov_ff_time.csv')
df2 = df2.groupby(geog_col).sum()[['sov_ff_time_wt']]
df = df2.merge(df, on=geog_col)

# Hours of delay from travel time (in min)
df['Total Delay Hours'] = (df['travtime_wt'] - df['sov_ff_time_wt'])/60

pd.options.display.float_format = '{:0,.0f}'.format
# Hours of delay for households in these locations
df[['Total Delay Hours']]

_df
# Out:
#                                   VHT % of VHT
# hh_city
# Algona                          2,288     0.1%
# Arlington                      13,970     0.4%
# Arlington UGA                     369     0.0%
# Auburn                         60,440     1.9%
# Auburn PAA                        290     0.0%
# Bainbridge Island              11,568     0.4%
# Bear Creek UPD                 10,112     0.3%
# Beaux Arts                        223     0.0%
# Bellevue                       95,716     3.1%
# Bellevue PAA                        7     0.0%
# Black Diamond                   4,807     0.2%
# Black Diamond PAA                 202     0.0%
# Bonney Lake                    17,296     0.6%
# Bonney Lake PAA                 6,488     0.2%
# Bothell                        37,058     1.2%
# Bothell MUGA                   26,563     0.9%
# Bremerton                      17,403     0.6%
# Bremerton UGA                   5,743     0.2%
# Brier                           5,937     0.2%
# Brier MUGA                      1,610     0.1%
# Buckley                         3,366     0.1%
# Burien                         37,325     1.2%
# Carbonado                         806     0.0%
# Carbonado PAA                       8     0.0%
# Carnation                       2,166     0.1%
# Carnation PAA                     208     0.0%
# Central Kitsap UGA             14,253     0.5%
# Clyde Hill                      1,917     0.1%
# Covington                      17,720     0.6%
# Darrington                      2,093     0.1%
# Darrington UGA                     93     0.0%
# Des Moines                     24,913     0.8%
# DuPont                          4,995     0.2%
# Duvall                          7,865     0.3%
# Duvall PAA                        201     0.0%
# Eatonville                      1,750     0.1%
# Eatonville PAA                    349     0.0%
# Edgewood                        9,873     0.3%
# Edmonds                        33,789     1.1%
# Edmonds MUGA                    3,109     0.1%
# Enumclaw                        8,250     0.3%
# Enumclaw PAA                      688     0.0%
# Everett                        74,056     2.4%
# Everett MUGA                   37,080     1.2%
# Federal Way                    73,431     2.4%
# Federal Way PAA                18,085     0.6%
# Fife                            7,166     0.2%
# Fife Milton Overlap               104     0.0%
# Fife PAA                          256     0.0%
# Fircrest                        3,986     0.1%
# Fircrest PAA                       27     0.0%
# Frederickson                      485     0.0%
# Gig Harbor                      5,353     0.2%
# Gig Harbor PAA                  4,081     0.1%
# Gold Bar                        3,330     0.1%
# Gold Bar UGA                    1,335     0.0%
# Granite Falls                   3,734     0.1%
# Granite Falls UGA                 189     0.0%
# Hunts Point                       365     0.0%
# Index                             187     0.0%
# Issaquah                       27,733     0.9%
# Issaquah PAA                      240     0.0%
# JBLM                            6,916     0.2%
# Kenmore                        21,615     0.7%
# Kent                           94,805     3.1%
# Kent PAA                          348     0.0%
# King-Rural                    143,757     4.6%
# Kingston UGA                    1,874     0.1%
# Kirkland                       67,259     2.2%
# Kitsap-Rural                   92,202     3.0%
# Lake Forest Park               12,344     0.4%
# Lake Stevens                   27,135     0.9%
# Lake Stevens UGA                5,146     0.2%
# Lake Stickney Gap               7,867     0.3%
# Lakewood                       36,513     1.2%
# Lakewood Steilacoom Overlap     1,601     0.1%
# Larch Way Overlap               4,037     0.1%
# Lynnwood                       25,293     0.8%
# Lynnwood MUGA                  24,539     0.8%
# Maltby UGA                        190     0.0%
# Maple Valley                   23,116     0.7%
# Marysville                     49,490     1.6%
# Marysville UGA                    152     0.0%
# Meadowdale Gap MUGA             2,675     0.1%
# Medina                          2,342     0.1%
# Mercer Island                  20,355     0.7%
# Mid-County                      6,818     0.2%
# Mill Creek                     17,836     0.6%
# Mill Creek MUGA                40,323     1.3%
# Milton                          6,419     0.2%
# Milton PAA                      1,178     0.0%
# Monroe                         12,162     0.4%
# Monroe UGA                      1,319     0.0%
# Mountlake Terrace              16,876     0.5%
# Mountlake Terrace MUGA             13     0.0%
# Mukilteo                       19,405     0.6%
# Mukilteo MUGA                  11,996     0.4%
# Newcastle                      11,183     0.4%
# Newcastle PAA                       6     0.0%
# Normandy Park                   5,473     0.2%
# North Bend                      5,324     0.2%
# North Bend PAA                  2,520     0.1%
# North Highline                 14,327     0.5%
# Orting                          7,377     0.2%
# PAINE FIELD AREA                   26     0.0%
# Pacific                         5,390     0.2%
# Pacific PAA                       775     0.0%
# Parkland-Spanaway-Midland      11,050     0.4%
# Pierce-Rural                  175,733     5.7%
# Port Orchard                    7,073     0.2%
# Port Orchard UGA                8,051     0.3%
# Poulsbo                         4,814     0.2%
# Poulsbo UGA                       330     0.0%
# Puyallup                       24,503     0.8%
# Puyallup PAA                    2,328     0.1%
# Puyallup PAA - HCT              3,185     0.1%
# Redmond                        44,390     1.4%
# Redmond PAA                     2,577     0.1%
# Renton                         81,368     2.6%
# Renton PAA                     45,154     1.5%
# Roy                             1,020     0.0%
# Roy PAA                             8     0.0%
# Ruston                            762     0.0%
# Sammamish                      58,809     1.9%
# Sammamish PAA                     493     0.0%
# SeaTac                         18,734     0.6%
# Seattle                       423,980    13.6%
# Seattle PAA                        61     0.0%
# Shoreline                      45,408     1.5%
# Silver Firs Gap MUGA           14,597     0.5%
# Silverdale                     11,045     0.4%
# Skykomish                         245     0.0%
# Snohomish                       7,294     0.2%
# Snohomish UGA                   1,207     0.0%
# Snohomish-Rural               151,733     4.9%
# Snoqualmie                     11,194     0.4%
# Snoqualmie PAA                    560     0.0%
# South Hill                     45,555     1.5%
# South Prairie                     597     0.0%
# South Prairie PAA                   4     0.0%
# Stanwood                        4,065     0.1%
# Stanwood UGA                      130     0.0%
# Steilacoom                      7,007     0.2%
# Sultan                          5,362     0.2%
# Sultan UGA                         77     0.0%
# Sumner                          6,476     0.2%
# Sumner PAA                      1,499     0.0%
# Tacoma                        130,904     4.2%
# Tacoma PAA                     46,109     1.5%
# Tukwila                        13,009     0.4%
# Tukwila PAA                         8     0.0%
# UU                             36,516     1.2%
# UUU                             3,633     0.1%
# University Place               22,422     0.7%
# Wilkeson                          421     0.0%
# Woodinville                     9,409     0.3%
# Woodway                         1,181     0.0%
# Woodway MUGA                        9     0.0%
# Yarrow Point                      842     0.0%
# Total                       3,106,305   100.0%

# %% [markdown]
# #### Average Delay Minutes per Household (per Weekday)

# %%
# Average minutes of delay per household
pd.options.display.float_format = '{:0,.1f}'.format
_df = _df_hh.merge(df[['Total Delay Hours']], left_index=True, right_index=True)
df['Avg. Minutes of Delay per Household'] = df['Total Delay Hours']/_df['hhexpfac']*60
df.to_csv(os.path.join(os.getcwd(), r'..\..\..\outputs\compare',geog,'7_delay.csv'))

df[['Avg. Minutes of Delay per Household']]
# Out:
#                              Avg. Minutes of Delay per Household
# hh_city
# Algona                                                      14.2
# Arlington                                                    3.4
# Arlington UGA                                                5.4
# Auburn                                                      13.5
# Auburn PAA                                                  14.9
# Bainbridge Island                                           -1.9
# Bear Creek UPD                                              16.5
# Beaux Arts                                                  13.4
# Bellevue                                                    11.4
# Bellevue PAA                                                12.2
# Black Diamond                                               17.4
# Black Diamond PAA                                           22.8
# Bonney Lake                                                 17.6
# Bonney Lake PAA                                             22.7
# Bothell                                                     17.8
# Bothell MUGA                                                20.7
# Bremerton                                                    0.7
# Bremerton UGA                                                3.1
# Brier                                                       19.8
# Brier MUGA                                                  20.0
# Buckley                                                      7.2
# Burien                                                       8.7
# Carbonado                                                   14.1
# Carbonado PAA                                               10.9
# Carnation                                                    6.2
# Carnation PAA                                                4.9
# Central Kitsap UGA                                           2.4
# Clyde Hill                                                  11.6
# Covington                                                   16.4
# Darrington                                                   5.5
# Darrington UGA                                               0.0
# Des Moines                                                  10.7
# DuPont                                                       8.9
# Duvall                                                      14.3
# Duvall PAA                                                  20.9
# Eatonville                                                  -2.0
# Eatonville PAA                                               7.5
# Edgewood                                                    15.3
# Edmonds                                                     12.8
# Edmonds MUGA                                                14.1
# Enumclaw                                                     9.4
# Enumclaw PAA                                                 9.9
# Everett                                                     10.3
# Everett MUGA                                                18.6
# Federal Way                                                 12.2
# Federal Way PAA                                             15.9
# Fife                                                        12.8
# Fife Milton Overlap                                         14.3
# Fife PAA                                                    14.8
# Fircrest                                                     7.5
# Fircrest PAA                                                 9.6
# Frederickson                                                17.5
# Gig Harbor                                                   6.2
# Gig Harbor PAA                                               7.6
# Gold Bar                                                    14.9
# Gold Bar UGA                                                17.2
# Granite Falls                                                3.9
# Granite Falls UGA                                            9.9
# Hunts Point                                                 11.8
# Index                                                        0.3
# Issaquah                                                    13.9
# Issaquah PAA                                                20.7
# JBLM                                                        14.7
# Kenmore                                                     19.5
# Kent                                                        14.0
# Kent PAA                                                    13.9
# King-Rural                                                  17.2
# Kingston UGA                                                -5.9
# Kirkland                                                    14.5
# Kitsap-Rural                                                 4.6
# Lake Forest Park                                            17.8
# Lake Stevens                                                16.0
# Lake Stevens UGA                                            19.0
# Lake Stickney Gap                                           18.6
# Lakewood                                                     7.6
# Lakewood Steilacoom Overlap                                  8.7
# Larch Way Overlap                                           23.2
# Lynnwood                                                    12.9
# Lynnwood MUGA                                               17.8
# Maltby UGA                                                  19.2
# Maple Valley                                                18.2
# Marysville                                                  13.5
# Marysville UGA                                              16.6
# Meadowdale Gap MUGA                                         18.8
# Medina                                                      11.7
# Mercer Island                                               15.9
# Mid-County                                                  15.6
# Mill Creek                                                  18.7
# Mill Creek MUGA                                             22.2
# Milton                                                      13.4
# Milton PAA                                                  14.8
# Monroe                                                       2.9
# Monroe UGA                                                  25.0
# Mountlake Terrace                                           16.3
# Mountlake Terrace MUGA                                      13.1
# Mukilteo                                                    17.4
# Mukilteo MUGA                                               17.9
# Newcastle                                                   18.4
# Newcastle PAA                                               22.9
# Normandy Park                                                9.3
# North Bend                                                   8.3
# North Bend PAA                                              12.5
# North Highline                                               9.7
# Orting                                                      25.3
# PAINE FIELD AREA                                            28.7
# Pacific                                                     15.3
# Pacific PAA                                                 18.6
# Parkland-Spanaway-Midland                                   16.2
# Pierce-Rural                                                15.2
# Port Orchard                                                 4.8
# Port Orchard UGA                                             5.4
# Poulsbo                                                     -0.9
# Poulsbo UGA                                                  0.1
# Puyallup                                                    11.2
# Puyallup PAA                                                11.1
# Puyallup PAA - HCT                                          15.1
# Redmond                                                     11.5
# Redmond PAA                                                 19.3
# Renton                                                      15.4
# Renton PAA                                                  18.1
# Roy                                                         22.9
# Roy PAA                                                     22.5
# Ruston                                                       5.1
# Sammamish                                                   21.1
# Sammamish PAA                                               21.2
# SeaTac                                                       8.2
# Seattle                                                      6.0
# Seattle PAA                                                 14.6
# Shoreline                                                   14.9
# Silver Firs Gap MUGA                                        24.4
# Silverdale                                                   5.1
# Skykomish                                                    3.3
# Snohomish                                                    7.2
# Snohomish UGA                                               15.9
# Snohomish-Rural                                             16.3
# Snoqualmie                                                  12.7
# Snoqualmie PAA                                              11.9
# South Hill                                                  18.7
# South Prairie                                               15.0
# South Prairie PAA                                            5.9
# Stanwood                                                   -15.9
# Stanwood UGA                                                -2.0
# Steilacoom                                                  11.6
# Sultan                                                      18.4
# Sultan UGA                                                  25.8
# Sumner                                                      11.1
# Sumner PAA                                                  18.1
# Tacoma                                                       7.7
# Tacoma PAA                                                  11.9
# Tukwila                                                      8.9
# Tukwila PAA                                                  5.9
# UU                                                          17.8
# UUU                                                         16.9
# University Place                                             8.5
# Wilkeson                                                    10.8
# Woodinville                                                 15.3
# Woodway                                                     19.8
# Woodway MUGA                                                16.6
# Yarrow Point                                                12.2
