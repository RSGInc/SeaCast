# %%
import os, sys, time
from scipy import stats
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
import pandas as pd
import numpy as np
from sqlalchemy import create_engine
# %matplotlib inline

from IPython.display import display, HTML

if (sys.version_info < (3, 0)):
    HTML('''<script>
    code_show=true; 
    function code_toggle() {
     if (code_show){
     $('div.input').hide();
     } else {
     $('div.input').show();
     }
     code_show = !code_show
    } 
    $( document ).ready(code_toggle);
    </script>
    <form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>''')

# %%
relative_path = '../../../../outputs'
pd.options.display.float_format = '{:0,.0f}'.format
format_percent = "{:,.2%}".format

# %%
conn = create_engine('sqlite:///../../../../inputs/db/soundcast_inputs.db')
df_obs = pd.read_sql("SELECT * FROM observed_bike_volumes", con=conn)

# %%
df_obs.groupby('County').size()
# Out:
# County
# King      276
# King       71
# Kitsap      5
# dtype: int64

# %%
df = pd.read_csv(os.path.join(relative_path,'network','network_results.csv'))

# %%
df.rename(columns={'@countyid':'County'}).groupby('County').size()
# Out:
# County
# 0      47202
# 5        456
# 33    589588
# 35     50969
# 53    209627
# 61    129707
# dtype: int64

# %%
df_seatac = df[df['@subarea_flag'] == 1]

# %% [markdown]
# ## Bike Count Scatter
# Both directions for all locations, each hour plotted separately

# %%
# Get only 2018 data for now
df_obs = df_obs[df_obs['Year'] == 2018]
df_obs = df_obs[['CountID','B_IJ_1', 'B_IJ_2', 'B_IJ_3', 'B_IJ_4', 'B_JI_1', 'B_JI_2', 'B_JI_3', 'B_JI_4']]
df_obs.index = df_obs.CountID
df_obs.drop(['CountID'], axis=1, inplace=True)
df_obs = df_obs.stack()
df_obs = df_obs.reset_index()
tod_map = {'B_IJ_1': '6to7',
           'B_JI_1': '6to7',
          'B_IJ_2': '7to8',
           'B_JI_2': '7to8',
          'B_IJ_3': '16to17',
           'B_JI_3': '16to17',
          'B_IJ_4': '17to18',
           'B_JI_4': '17to18'}
df_obs['tod'] = df_obs['level_1'].map(tod_map)
df_obs.drop('level_1', axis=1, inplace=True)
df_obs.rename(columns={0: 'observed'}, inplace=True)
df_obs['observed'] = df_obs['observed'].astype('float')
df_obs = df_obs.groupby(['CountID','tod']).sum()[['observed']]
df_obs = df_obs.reset_index()

# Group both directions
_df = df[df['@countid'].isin(df_obs['CountID'])]
_df = _df.groupby(['tod','@countid']).sum()[['@bvol']]
_df = _df.reset_index()
_
df_compare = _df[['@countid','tod','@bvol']].merge(df_obs, left_on=['@countid','tod'], right_on=['CountID','tod'])
df_compare[['@bvol','observed']].plot(kind='scatter', x='observed', y='@bvol')
# Out:
# <AxesSubplot:xlabel='observed', ylabel='@bvol'>

# %%
slope, intercept, r_value, p_value, std_err = stats.linregress(df_compare['observed'],
                                                               df_compare['@bvol'])
print('r^2: ' + str(r_value))
# Out:
# r^2: 0.7273546191123024

# %% [markdown]
# ## Total Volume
# Both directions on link across all observed time periods
# Note that this does not represent daily volumes but the totals for when observed data is available, summed together

# %%
# Combine all count totals available
df_daily = df_compare.groupby('CountID').sum()[['@bvol','observed']]
df_daily[['@bvol','observed']].plot(kind='scatter', x='observed', y='@bvol')
# Out:
# <AxesSubplot:xlabel='observed', ylabel='@bvol'>

# %%
slope, intercept, r_value, p_value, std_err = stats.linregress(df_daily['observed'],
                                                               df_daily['@bvol'])
print('r^2: ' + str(r_value))
# Out:
# r^2: 0.8001968079793726

# %% [markdown]
# ## Top 30 Locations by Observed Volume
# Using the total volume as defined directly above

# %%
df_daily['diff'] = df_daily['@bvol'] - df_daily['observed']
df_daily['percent_diff'] = df_daily['diff']/df_daily['observed']

# Merge with observed data to get more location context
df_obs = pd.read_sql("SELECT * FROM observed_bike_volumes WHERE year == 2018", con=conn)
df = df_daily.merge(df_obs[['CountID','Jurisdiction','CrossStreets',
                           'Latitude','Longitude','Directions',
                           'PSRCEdgeID']], on='CountID', how='left')

# %%
df = df.drop_duplicates()
format_percent = "{:,.2%}".format
_df = df.sort_values('observed',ascending=False).iloc[0:30]
_df[['percent_diff']] = _df[['percent_diff']].applymap(format_percent)
_df.columns = _df.columns.str.replace('@','')
_df
# Out:
#      CountID  bvol  observed  diff percent_diff       Jurisdiction  \
# 13      6001 1,268     1,303   -35       -2.70%            Seattle
# 20      6009   297       914  -617      -67.49%            Seattle
# 19      6008    19       520  -501      -96.30%            Seattle
# 15      6003   752       389   363       93.22%            Seattle
# 14      6002   446       388    58       14.95%            Seattle
# 217     6252   583       375   208       55.32%             Medina
# 222     6257    74       346  -272      -78.64%            Seattle
# 17      6005    26       315  -289      -91.75%            Seattle
# 21      6011   380       257   123       47.63%            Seattle
# 216     6251   302       230    72       31.49%   Lake Forest Park
# 218     6253   116       227  -111      -48.81%            Redmond
# 225     6260   207       219   -12       -5.58%        Woodinville
# 213     6248    23       206  -183      -88.85%            Kenmore
# 18      6007   439       177   262      147.76%            Seattle
# 223     6258    16       121  -105      -86.73%            Seattle
# 16      6004   568       113   455      400.99%            Seattle
# 209     6244   181       101    80       78.59%           Bellevue
# 220     6255    31       101   -70      -69.32%            Redmond
# 219     6254    72        85   -13      -15.57%            Redmond
# 208     6242     0        52   -52     -100.00%  Bainbridge Island
# 221     6256    21        37   -16      -43.29%             Renton
# 22      6025    35        33     2        7.18%           Bellevue
# 215     6250   132        33    99      299.82%           Kirkland
# 224     6259    27        31    -4      -14.24%            Tukwila
# 212     6247    12        12     0        2.56%           Issaquah
# 79      6107    36         6    30      500.00%        Federal Way
# 174     6204    30         5    25      505.00%        Federal Way
# 75      6103    27         5    22      440.00%        Federal Way
# 8       5018    18         4    14      350.00%        Federal Way
# 80      6108    36         4    32      800.00%        Federal Way
#
#                                           CrossStreets   Latitude  \
# 13                                      Fremont Bridge       None
# 20                          Westlake PBL at Newton St        None
# 19            Elliott Bay Trail at Myrtle Edwards Park       None
# 15                    2nd Ave and Madison N of Marion        None
# 14   Spokane Street and near 11th Ave SW (W Seattle...       None
# 217                SR 520 Trail (East bridge approach)  47.637778
# 222                    UW Transit Center 2 Loops South  47.650394
# 17                   Burke Gilman Trail and NE 70th St       None
# 21                               2nd Ave S of Cedar St       None
# 216                                 BURKE GILMAN TRAIL  47.753247
# 218                              SAMMAMISH RIVER TRAIL  47.679959
# 225                  SAMMAMISH RIVER TRAIL WOODINVILLE   47.74601
# 213                               Burke Gilman Kenmore   47.75683
# 18                        MTS Trail West of I90 Bridge       None
# 223                    UW Transit Center 3 Loops North  47.650462
# 16                                  Broadway and Union       None
# 209                            BELLEVUE SR 520 TRAIL 1  47.631078
# 220                           Marymoor Connector Trail  47.664023
# 219       EAST LAKE SAMMAMISH TRAIL LOCATION 1 REDMOND  47.660961
# 208            Bainbridge Island Winslow Way Bike Only  47.624948
# 221                  Cedar River Trail E O 154th PL SE  47.465576
# 22   Eastside Rail Corridor Trail (NB and SB), IN =...       None
# 215       Eastside Rail Corridor Trail at 108th Ave NE  47.643944
# 224        Green River Trail Cecil Moses Memorial Park  47.502925
# 212                             Issaquah Preston Trail  47.534849
# 79                  8th Ave SW and SW 312th St (N leg)       None
# 174                          1st Way S and SW 340th St       None
# 75                          8th Ave SW and SW 312th St       None
# 8                           32nd Ave S and SW 320th St       None
# 80                  8th Ave SW and SW 312th St (S leg)       None
#
#        Longitude                                    Directions  PSRCEdgeID
# 13          None  IJ NB (East sidewalk); JI SB (West sidewalk)     202,159
# 20          None                                  IJ NB; JI SB     226,819
# 19          None                                  IJ NB; JI SB     250,276
# 15          None                                  IJ SB; JI NB     182,062
# 14          None                                  IJ WB; JI EB     224,082
# 217   122.238861                                          None     226,586
# 222   122.304917                                          None         NaN
# 17          None                                  IJ NB; JI SB     228,459
# 21          None                                  IJ SB; JI NB     183,166
# 216   122.276939                                          None     231,131
# 218   122.131915                                          None     250,127
# 225   122.158524                                          None     231,142
# 213    122.24136                                          None     231,298
# 18          None                                  IJ EB; JI WB     242,950
# 223   122.304971                                          None         NaN
# 16          None                                  IJ NB; JI SB     182,920
# 209   122.174834                                          None     226,345
# 220   122.118041                                          None     227,588
# 219   122.097206                                          None     227,464
# 208   122.515641                                          None     244,904
# 221   122.136985                                          None     219,164
# 22          None                                          None     250,851
# 215   122.194258                                          None     185,960
# 224  122.2977028                                          None     220,839
# 212   122.029982                                          None     222,481
# 79          None                                          None     167,915
# 174         None                                          None     166,817
# 75          None                                          None     167,948
# 8           None                                          None     167,546
# 80          None                                          None     167,907

# %% [markdown]
# # Top 30 Locations by Modeled Volume

# %%
df = df.drop_duplicates()
format_percent = "{:,.2%}".format
_df = df.sort_values('@bvol',ascending=False).iloc[0:30]
_df[['percent_diff']] = _df[['percent_diff']].applymap(format_percent)
_df.columns = _df.columns.str.replace('@','')
_df
# Out:
#      CountID  bvol  observed  diff percent_diff      Jurisdiction  \
# 13      6001 1,268     1,303   -35       -2.70%           Seattle
# 15      6003   752       389   363       93.22%           Seattle
# 217     6252   583       375   208       55.32%            Medina
# 16      6004   568       113   455      400.99%           Seattle
# 14      6002   446       388    58       14.95%           Seattle
# 18      6007   439       177   262      147.76%           Seattle
# 21      6011   380       257   123       47.63%           Seattle
# 216     6251   302       230    72       31.49%  Lake Forest Park
# 20      6009   297       914  -617      -67.49%           Seattle
# 225     6260   207       219   -12       -5.58%       Woodinville
# 209     6244   181       101    80       78.59%          Bellevue
# 215     6250   132        33    99      299.82%          Kirkland
# 218     6253   116       227  -111      -48.81%           Redmond
# 222     6257    74       346  -272      -78.64%           Seattle
# 219     6254    72        85   -13      -15.57%           Redmond
# 50      6078    69         1    68    6,800.00%       Federal Way
# 53      6081    69         1    68    6,800.00%       Federal Way
# 204     6238    50         1    50    4,950.00%       Federal Way
# 205     6239    50         1    50    4,950.00%       Federal Way
# 39      6067    48         1    47    4,700.00%       Federal Way
# 31      6059    48         0    48         inf%       Federal Way
# 58      6086    47         0    47         inf%       Federal Way
# 195     6227    46         3    42    1,416.67%       Federal Way
# 67      6095    45         2    43    2,162.50%       Federal Way
# 65      6093    44         0    44         inf%       Federal Way
# 68      6096    44         0    44         inf%       Federal Way
# 211     6246    41         4    37    1,048.46%          Issaquah
# 32      6060    41         1    40    3,975.00%       Federal Way
# 128     6158    37         0    37         inf%       Federal Way
# 127     6157    36         0    36         inf%       Federal Way
#
#                                           CrossStreets   Latitude   Longitude  \
# 13                                      Fremont Bridge       None        None
# 15                    2nd Ave and Madison N of Marion        None        None
# 217                SR 520 Trail (East bridge approach)  47.637778  122.238861
# 16                                  Broadway and Union       None        None
# 14   Spokane Street and near 11th Ave SW (W Seattle...       None        None
# 18                        MTS Trail West of I90 Bridge       None        None
# 21                               2nd Ave S of Cedar St       None        None
# 216                                 BURKE GILMAN TRAIL  47.753247  122.276939
# 20                          Westlake PBL at Newton St        None        None
# 225                  SAMMAMISH RIVER TRAIL WOODINVILLE   47.74601  122.158524
# 209                            BELLEVUE SR 520 TRAIL 1  47.631078  122.174834
# 215       Eastside Rail Corridor Trail at 108th Ave NE  47.643944  122.194258
# 218                              SAMMAMISH RIVER TRAIL  47.679959  122.131915
# 222                    UW Transit Center 2 Loops South  47.650394  122.304917
# 219       EAST LAKE SAMMAMISH TRAIL LOCATION 1 REDMOND  47.660961  122.097206
# 50                      Pacific Hwy S and S Dash Pt Rd       None        None
# 53                        Pacific Hwy S and 18th Ave S       None        None
# 204    Enchanted Pkwy S and SR 18   SR 161 SB Off Ramp       None        None
# 205                   Enchanted Pkwy S and Milton Rd S       None        None
# 39                          Military Rd S and 288th St       None        None
# 31                        Military Rd S and S 284th St       None        None
# 58                       Pacific Hwy S and SW 304th St       None        None
# 195                       20th Ave SW and SW 356th St        None        None
# 67                          31st Ave S and Military Rd       None        None
# 65                       Pacific Hwy S and SW 308th St       None        None
# 68                       Pacific Hwy S and SW 310th St       None        None
# 211      EAST LAKE SAMMAMISH TRAIL LOCATION 2 ISSAQUAH  47.543069  122.040338
# 32                        Pacific Hwy S and S 288th St       None        None
# 128                           Military Rd and 320th St       None        None
# 127                           Military Rd and 320th St       None        None
#
#                                        Directions  PSRCEdgeID
# 13   IJ NB (East sidewalk); JI SB (West sidewalk)     202,159
# 15                                   IJ SB; JI NB     182,062
# 217                                          None     226,586
# 16                                   IJ NB; JI SB     182,920
# 14                                   IJ WB; JI EB     224,082
# 18                                   IJ EB; JI WB     242,950
# 21                                   IJ SB; JI NB     183,166
# 216                                          None     231,131
# 20                                   IJ NB; JI SB     226,819
# 225                                          None     231,142
# 209                                          None     226,345
# 215                                          None     185,960
# 218                                          None     250,127
# 222                                          None         NaN
# 219                                          None     227,464
# 50                                           None     149,170
# 53                                           None     149,150
# 204                                          None     166,130
# 205                                          None     165,991
# 39                                           None     168,480
# 31                                           None     168,543
# 58                                           None     168,091
# 195                                          None     166,161
# 67                                           None     168,035
# 65                                           None     168,012
# 68                                           None     167,977
# 211                                          None     222,664
# 32                                           None      57,969
# 128                                          None     167,539
# 127                                          None     167,639

# %% [markdown]
# ## City of SeaTac Counts

# %%
df_daily = df_compare.groupby('CountID').sum()[['@bvol','observed']]
df_seatac = df_seatac.drop_duplicates()
format_percent = "{:,.2%}".format
_df_seatac = df_seatac.sort_values('@bvol',ascending=False).iloc[0:30]
_df_seatac.columns = _df_seatac.columns.str.replace('@','')
_df_seatac[['bvol', 'corridorid', 'countid', 'countyid', 'facilitytype']]
# Out:
#         bvol  corridorid  countid  countyid  facilitytype
# 477654    64           0        0        33             7
# 478109    64           0   20,210        33             7
# 476669    64           0        0        33             7
# 476672    63           0        0        33             7
# 476653    58           0        0        33             7
# 476660    58           0   20,202        33             7
# 476627    55           0        0        33             7
# 480114    54           0        0        33             7
# 472813    53      30,113        0        33             5
# 472807    53      30,113        0        33             5
# 472832    53      30,113        0        33             5
# 472787    52      30,113        0        33             5
# 472746    52      30,113   20,091        33             5
# 472921    52      30,114        0        33             5
# 472912    51      30,114        0        33             5
# 472910    51      30,114        0        33             5
# 472907    51      30,114        0        33             5
# 475976    50           0        0        33             7
# 481406    50           0        0        33             6
# 475453    50           0        0        33             7
# 478520    49           0   20,210        33             7
# 478108    49           0        0        33             7
# 478522    49           0        0        33             7
# 478884    49           0        0        33             7
# 472982    49      30,114   20,066        33             5
# 472990    49      30,114        0        33             5
# 470273    49           0        0        33             6
# 470394    49           0        0        33             6
# 472675    48      30,114        0        33             5
# 472954    48      30,114   20,096        33             5
